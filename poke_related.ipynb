# %%
import credential
APP_KEY = credential.login['APP_KEY']
APP_SECRET = credential.login['APP_SECRET']
OAUTH_TOKEN = credential.login['OAUTH_TOKEN']
OAUTH_TOKEN_SECRET = credential.login['OAUTH_TOKEN_SECRET']

# %%
from twython import Twython
twitter = Twython(APP_KEY, APP_SECRET, OAUTH_TOKEN,
    OAUTH_TOKEN_SECRET)

results = twitter.search( q='pokeman go')
#for result in results:
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d644c4632b95> in <module>()
#       6 #for result in results:
#       7 #    print result
# ----> 8 print json.dump(results)
#
# NameError: name 'json' is not defined

# %%
import json
#    print result
print json.dumps(results, indent = 1)
# Out:
# {
#  "search_metadata": {
#   "count": 15,
#   "completed_in": 0.065,
#   "max_id_str": "755891298775789568",
#   "since_id_str": "0",
#   "next_results": "?max_id=755888877185830911&q=pokeman%20go&include_entities=1",
#   "refresh_url": "?since_id=755891298775789568&q=pokeman%20go&include_entities=1",
#   "since_id": 0,
#   "query": "pokeman+go",
#   "max_id": 755891298775789568
#  },
#  "statuses": [
#   {
#    "contributors": null,
#    "truncated": false,
#    "text": "I love Pokeman on the go",
#    "is_quote_status": false,
#    "in_reply_to_status_id": null,
#    "id": 755891298775789568,
#    "favorite_count": 0,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [],
#     "hashtags": [],
#     "urls": []
#    },
#    "retweeted": false,
#    "coordinates": null,
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 0,
# ...

# %%
import sys
import csv
from twitter import *

# %%
latitude = 37.76	# geographical centre of search
longitude = -122.46	# geographical centre of search
max_range = 100 			# search range in kilometres
num_results = 500		# minimum results to obtain
outfile = "output.csv"

# %%
#-----------------------------------------------------------------------
# open a file to write (mode "w"), and create a CSV writer object
#-----------------------------------------------------------------------
csvfile = file(outfile, "w")
csvwriter = csv.writer(csvfile)
#-----------------------------------------------------------------------
# add headings to our CSV file
#-----------------------------------------------------------------------
row = [ "user", "text", "latitude", "longitude" ]
csvwriter.writerow(row)

# %%
#-----------------------------------------------------------------------
# create twitter API object
#-----------------------------------------------------------------------
twitter = Twitter(
		        auth = OAuth(OAUTH_TOKEN,
    OAUTH_TOKEN_SECRET,APP_KEY, APP_SECRET, ))

# %%
#-----------------------------------------------------------------------
# the twitter API only allows us to query up to 100 tweets at a time.
# to search for more, we will break our search up into 10 "pages", each
# of which will include 100 matching tweets.
#-----------------------------------------------------------------------
result_count = 0
last_id = None
while result_count <  num_results:
	#-----------------------------------------------------------------------
	# perform a search based on latitude and longitude
	# twitter API docs: https://dev.twitter.com/docs/api/1/get/search
	#-----------------------------------------------------------------------
	query = twitter.search.tweets(q = "pokemon go", geocode = "%f,%f,%dkm" % (latitude, longitude, max_range), count = 100, max_id = last_id)

	for result in query["statuses"]:
		#-----------------------------------------------------------------------
		# only process a result if it has a geolocation
		#-----------------------------------------------------------------------
		if result["geo"]:
			user = result["user"]["screen_name"]
			text = result["text"]
			text = text.encode('ascii', 'replace')
			latitude = result["geo"]["coordinates"][0]
			longitude = result["geo"]["coordinates"][1]

			# now write this row to our CSV file
			row = [ user, text, latitude, longitude ]
			csvwriter.writerow(row)
			result_count += 1
		last_id = result["id"]

	#-----------------------------------------------------------------------
	# let the user know where we're up to
	#-----------------------------------------------------------------------
	print "got %d results" % result_count
# Out:
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# got 0 results
# ...

# %%
csvfile.close()

print "written to %s" % outfile
# Out:
# written to output.csv
